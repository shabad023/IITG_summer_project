# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from time import time

# Task 1: Build the Graph
# Take raw delivery data → figure out which hubs connect to which → calculate how delayed each route typically is → build a graph.
# Task 2: Find Bottleneck Hubs
# Some hubs cause the most delays. Find them using math (betweenness centrality = how many routes pass through this hub). If a hub is on every route AND is slow → it's a chokepoint.
# Task 3: Better ETA(estimated time of arrival) Prediction
# Currently OSRM predicts ETAs ignoring the graph. You'll build:
# A basic model (using simple features like distance, time of day)
# A graph-enhanced model (that also uses "this hub is historically slow")
# Show the graph model is more accurate
# Task 4: FTL vs Carting Decision
# FTL = Full Truck Load (one truck, direct route, expensive but fast)
# Carting = Shared transport (cheaper but slower, goes through hubs)
# Build a framework that recommends which to use based on the corridor and timing.
# Task 5: Strategy Memo
# Write a 1-2 page report for a business leader (not technical) saying:
# "These 5 hubs are your biggest problems"
# "Here's what to do about them"
# "Here's how much money you'll save"


# This project sounds like you need to know GraphSAGE, node2vec, ML pipelines, graph theory — all at once. You don't. Here's the secret:

# 80% of the value comes from Tasks 1, 2, and 5. The graph model (Task 3) can be a simple gradient boosting model with graph features added. That's enough to "demonstrably outperform" a baseline.

# %%
df=pd.read_csv('/Users/shabadpreetsingh/Downloads/IITG Project/delivery_data.csv')
df.head(5)
# Out:
#        data  trip_creation_time  \
# 0  training  2018-09-20 2:35:36
# 1  training  2018-09-20 2:35:36
# 2  training  2018-09-20 2:35:36
# 3  training  2018-09-20 2:35:36
# 4  training  2018-09-20 2:35:36
#
#                                  route_schedule_uuid route_type  \
# 0  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4  thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
#
#                  trip_uuid source_center                 source_name  \
# 0  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 1  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 2  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# 3  trip-153741093647649320  IND388121AAA  Anand_VUNagar_DC (Gujarat)
# ...

# %%
df.shape
# Out:
# (144867, 24)

# %%
delivery_data=df.copy()

# %%
delivery_data.describe()
# Out:
#        start_scan_to_end_scan  cutoff_factor  actual_distance_to_destination  \
# count           144867.000000  144867.000000                   144867.000000
# mean               961.262986     232.926567                      234.073372
# std               1037.012769     344.755577                      344.990009
# min                 20.000000       9.000000                        9.000045
# 25%                161.000000      22.000000                       23.355874
# 50%                449.000000      66.000000                       66.126571
# 75%               1634.000000     286.000000                      286.708875
# max               7898.000000    1927.000000                     1927.447705
#
#          actual_time      osrm_time  osrm_distance         factor  \
# count  144867.000000  144867.000000  144867.000000  144867.000000
# mean      416.927527     213.868272     284.771297       2.120107
# std       598.103621     308.011085     421.119294       1.715421
# ...

# %%
delivery_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144867 entries, 0 to 144866
# Data columns (total 24 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   data                            144867 non-null  object
#  1   trip_creation_time              144867 non-null  object
#  2   route_schedule_uuid             144867 non-null  object
#  3   route_type                      144867 non-null  object
#  4   trip_uuid                       144867 non-null  object
#  5   source_center                   144867 non-null  object
#  6   source_name                     144574 non-null  object
#  7   destination_center              144867 non-null  object
#  8   destination_name                144606 non-null  object
#  9   od_start_time                   144867 non-null  object
#  10  od_end_time                     144867 non-null  object
#  11  start_scan_to_end_scan          144867 non-null  int64
# ...

# %%
#jo rows puri nahi hai
#source_name                     144574
#destination_name                144606

# %%
delivery_data.describe(include='all')
# Out:
#             data   trip_creation_time  \
# count     144867               144867
# unique         2                14754
# top     training  2018-09-13 19:44:52
# freq      104858                  122
# mean         NaN                  NaN
# std          NaN                  NaN
# min          NaN                  NaN
# 25%          NaN                  NaN
# 50%          NaN                  NaN
# 75%          NaN                  NaN
# max          NaN                  NaN
#
#                                       route_schedule_uuid route_type  \
# count                                              144867     144867
# unique                                               1504          2
# top     thanos::sroute:4029a8a2-6c74-4b7e-a6d8-f9e069f...        FTL
# freq                                                 1812      99660
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# ...

# %%
df.dtypes
# Out:
# data                               object
# trip_creation_time                 object
# route_schedule_uuid                object
# route_type                         object
# trip_uuid                          object
# source_center                      object
# source_name                        object
# destination_center                 object
# destination_name                   object
# od_start_time                      object
# od_end_time                        object
# start_scan_to_end_scan              int64
# is_cutoff                            bool
# cutoff_factor                       int64
# cutoff_timestamp                   object
# actual_distance_to_destination    float64
# actual_time                         int64
# osrm_time                           int64
# osrm_distance                     float64
# factor                            float64
# segment_actual_time                 int64
# segment_osrm_time                   int64
# ...

# %%
#trip_creation_time                 object-date time ch
#od_start_time                      object-date time ch
#od_end_time                        object-date time ch
#cutoff_timestamp                   object-date time ch convert karna

# %%
df['trip_creation_time'] = pd.to_datetime(df['trip_creation_time'])
df['od_start_time'] = pd.to_datetime(df['od_start_time'])
df['od_end_time'] = pd.to_datetime(df['od_end_time'])
df['cutoff_timestamp'] = pd.to_datetime(df['cutoff_timestamp'])

# %%
df.dtypes
# Out:
# data                                      object
# trip_creation_time                datetime64[ns]
# route_schedule_uuid                       object
# route_type                                object
# trip_uuid                                 object
# source_center                             object
# source_name                               object
# destination_center                        object
# destination_name                          object
# od_start_time                     datetime64[ns]
# od_end_time                       datetime64[ns]
# start_scan_to_end_scan                     int64
# is_cutoff                                   bool
# cutoff_factor                              int64
# cutoff_timestamp                  datetime64[ns]
# actual_distance_to_destination           float64
# actual_time                                int64
# osrm_time                                  int64
# osrm_distance                            float64
# ...

# %%
#test and training ko split kar diya
training_data = delivery_data[delivery_data['data'] == 'training']
test_data = delivery_data[delivery_data['data'] == 'test']

# %%
test_data.shape
# Out:
# (40009, 24)

# %%
training_data.shape
# Out:
# (104858, 24)

# %%
training_data
# Out:
#             data   trip_creation_time  \
# 0       training   2018-09-20 2:35:36
# 1       training   2018-09-20 2:35:36
# 2       training   2018-09-20 2:35:36
# 3       training   2018-09-20 2:35:36
# 4       training   2018-09-20 2:35:36
# ...          ...                  ...
# 144862  training  2018-09-20 16:24:28
# 144863  training  2018-09-20 16:24:28
# 144864  training  2018-09-20 16:24:28
# 144865  training  2018-09-20 16:24:28
# 144866  training  2018-09-20 16:24:28
#
#                                       route_schedule_uuid route_type  \
# 0       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 1       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 2       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 3       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# 4       thanos::sroute:eb7bfc78-b351-4c0e-a951-fa3d5c3...    Carting
# ...                                                   ...        ...
# ...

# %%
delivery_data[delivery_data['source_name'].isnull()]
# Out:
#             data  trip_creation_time  \
# 112     training  2018-09-25 8:53:04
# 113     training  2018-09-25 8:53:04
# 114     training  2018-09-25 8:53:04
# 115     training  2018-09-25 8:53:04
# 116     training  2018-09-25 8:53:04
# ...          ...                 ...
# 144484      test  2018-10-03 9:06:07
# 144485      test  2018-10-03 9:06:07
# 144486      test  2018-10-03 9:06:07
# 144487      test  2018-10-03 9:06:07
# 144488      test  2018-10-03 9:06:07
#
#                                       route_schedule_uuid route_type  \
# 112     thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...        FTL
# 113     thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...        FTL
# 114     thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...        FTL
# 115     thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...        FTL
# 116     thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...        FTL
# ...                                                   ...        ...
# ...

# %%
delivery_data[delivery_data['destination_name'].isnull()]
# Out:
#             data   trip_creation_time  \
# 110     training   2018-09-25 8:53:04
# 111     training   2018-09-25 8:53:04
# 982         test  2018-10-01 20:56:18
# 983         test  2018-10-01 20:56:18
# 4882    training   2018-09-24 7:18:06
# ...          ...                  ...
# 144478      test   2018-10-03 9:06:07
# 144479      test   2018-10-03 9:06:07
# 144480      test   2018-10-03 9:06:07
# 144481      test   2018-10-03 9:06:07
# 144482      test   2018-10-03 9:06:07
#
#                                       route_schedule_uuid route_type  \
# 110     thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...        FTL
# 111     thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...        FTL
# 982     thanos::sroute:d0ebdacd-e09b-47d3-be77-c9c4a05...        FTL
# 983     thanos::sroute:d0ebdacd-e09b-47d3-be77-c9c4a05...        FTL
# 4882    thanos::sroute:2f43f11e-d3ba-4590-9355-82928e1...        FTL
# ...                                                   ...        ...
# ...

# %%
delivery_data.loc[110]

#* pandas row 110
    # = Excel visible row 112
# Out:
# data                                                                       training
# trip_creation_time                                               2018-09-25 8:53:04
# route_schedule_uuid               thanos::sroute:4460a38d-ab9b-484e-bd4e-f4201d0...
# route_type                                                                      FTL
# trip_uuid                                                   trip-153786558437756691
# source_center                                                          IND342601AAA
# source_name                                        Piparcity_BsstdDPP_D (Rajasthan)
# destination_center                                                     IND342902A1B
# destination_name                                                                NaN
# od_start_time                                                    2018-09-26 5:04:49
# od_end_time                                                      2018-09-26 6:58:08
# ...

# %%
delivery_data[
    delivery_data['source_name'].isnull()
]['source_center'].unique()

#10 hai
# Out:
# array(['IND342902A1B', 'IND577116AAA', 'IND282002AAD', 'IND465333A1B',
#        'IND841301AAC', 'IND509103AAC', 'IND126116AAA', 'IND331022A1B',
#        'IND505326AAB', 'IND852118A1B'], dtype=object)

# %%
delivery_data[
    delivery_data['destination_name'].isnull()
]['destination_center'].unique()

#13 hai
# Out:
# array(['IND342902A1B', 'IND577116AAA', 'IND282002AAD', 'IND465333A1B',
#        'IND841301AAC', 'IND505326AAB', 'IND852118A1B', 'IND126116AAA',
#        'IND509103AAC', 'IND221005A1A', 'IND250002AAC', 'IND331001A1C',
#        'IND122015AAC'], dtype=object)

# %%
delivery_data[
    (delivery_data['source_name'].isnull()) &
    (delivery_data['destination_name'].isnull())
]
# Out:
#            data   trip_creation_time  \
# 68006  training  2018-09-26 22:21:57
# 68007  training  2018-09-26 22:21:57
# 68008  training  2018-09-26 22:21:57
#
#                                      route_schedule_uuid route_type  \
# 68006  thanos::sroute:cfb575b8-df26-48f5-8427-6f48f9d...        FTL
# 68007  thanos::sroute:cfb575b8-df26-48f5-8427-6f48f9d...        FTL
# 68008  thanos::sroute:cfb575b8-df26-48f5-8427-6f48f9d...        FTL
#
#                      trip_uuid source_center source_name destination_center  \
# 68006  trip-153800051661903546  IND331022A1B         NaN       IND331001A1C
# 68007  trip-153800051661903546  IND331022A1B         NaN       IND331001A1C
# 68008  trip-153800051661903546  IND331022A1B         NaN       IND331001A1C
#
#       destination_name       od_start_time  ...    cutoff_timestamp  \
# 68006              NaN  2018-09-27 3:19:15  ...  2018-09-27 5:01:28
# 68007              NaN  2018-09-27 3:19:15  ...  2018-09-27 3:33:17
# ...

# %%
list1 = [
    'IND342902A1B', 'IND577116AAA', 'IND282002AAD',
    'IND465333A1B', 'IND841301AAC', 'IND509103AAC',
    'IND126116AAA', 'IND331022A1B', 'IND505326AAB',
    'IND852118A1B'
]

list2 = [
    'IND342902A1B', 'IND577116AAA', 'IND282002AAD',
    'IND465333A1B', 'IND841301AAC', 'IND505326AAB',
    'IND852118A1B', 'IND126116AAA', 'IND509103AAC',
    'IND221005A1A', 'IND250002AAC', 'IND331001A1C',
    'IND122015AAC'
]

common_values = set(list1) & set(list2)

print(common_values)
# Out:
# {'IND505326AAB', 'IND465333A1B', 'IND509103AAC', 'IND282002AAD', 'IND342902A1B', 'IND577116AAA', 'IND852118A1B', 'IND126116AAA', 'IND841301AAC'}

# %%
print(delivery_data['route_type'].value_counts())
#counts FTL v/s Carting values
# Out:
# route_type
# FTL        99660
# Carting    45207
# Name: count, dtype: int64

# %%
#factor jo ki most important cheez hai usse samajhna
print(delivery_data['factor'].describe())
#min max important hoga
# Out:
# count    144867.000000
# mean          2.120107
# std           1.715421
# min           0.144000
# 25%           1.604264
# 50%           1.857143
# 75%           2.213483
# max          77.387097
# Name: factor, dtype: float64

# %%
plt.figure(figsize=(16,6))

plt.hist(delivery_data['factor'], bins=70)
plt.xlim(0,20)
plt.yticks(np.arange(0, 110000, 10000))
plt.xticks(np.arange(0, 21, .5))
plt.xlabel('Factor')
plt.ylabel('Frequency')
plt.title('Distribution of Factor')

plt.show()

# %%
plt.figure(figsize=(16,6))

plt.hist(delivery_data['factor'], bins=70)

plt.xlabel('Factor')
plt.ylabel('Frequency')
plt.title('Distribution of Factor')

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.hist(delivery_data['factor'], bins=70)

plt.xlim(0,20)

plt.yticks(np.arange(0, 110000, 10000))

plt.xticks(
    np.arange(0, 15, 0.5),
    rotation=45
)

plt.xlabel('Factor')
plt.ylabel('Frequency')
plt.title('Distribution of Factor')

plt.show()

# %%
plt.figure(figsize=(12,6))

plt.hist(delivery_data['factor'], bins=70)

plt.xlim(0,10)

plt.yticks(np.arange(0, 110000, 10000))

plt.xticks(np.arange(0, 10.5, 0.5))

plt.xlabel('Factor')
plt.ylabel('Frequency')
plt.title('Distribution of Factor')

plt.show()
